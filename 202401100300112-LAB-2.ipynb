# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))

def sigmoid_derivative(x):
  return x * (1-x)

# %%
X= np.linspace(0,1,100).reshape(-1,1)
Y= 2*X

# %%
np.random.seed(42)

# %%
input_size= 1
hidden_size= 5
output_size= 1

# %%
w1= np.random.randn(input_size,hidden_size)*0.1
b1= np.zeros((1,hidden_size))

w2= np.random.randn(hidden_size, output_size)*0.1
b2= np.zeros((1,output_size))

# %%
learning_rate= 0.5
epochs=2000
losses =[]

# %%
for epoch in range(epochs):
  z1= np.dot(X,w1)+b1
  a1=sigmoid(z1)

  z2= np.dot(a1,w2)+b2
  y_pred= sigmoid(z2)

  loss = np.mean((Y - y_pred) ** 2)
  losses.append(loss)

  d_output = (y_pred - Y) * sigmoid_derivative(y_pred)


  dW2 = np.dot(a1.T, d_output)
  db2 = np.sum(d_output, axis=0, keepdims=True)


  d_hidden = np.dot(d_output, w2.T) * sigmoid_derivative(a1)


  dW1 = np.dot(X.T, d_hidden)
  db1 = np.sum(d_hidden, axis=0, keepdims=True)


  w2 -= learning_rate * dW2
  b2 -= learning_rate * db2

  w1 -= learning_rate * dW1
  b1 -= learning_rate * db1

# %%
print(len(losses))
# Out:
# 0

# %%
plt.plot(losses)
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Training Loss vs Epoch")
plt.show()

# %%
X_test = np.array([[0.2], [0.5], [0.8]])
z1_test = np.dot(X_test, w1) + b1
a1_test = sigmoid(z1_test)
z2_test = np.dot(a1_test, w2) + b2
y_test_pred = sigmoid(z2_test)
# Out:
# /tmp/ipython-input-709137497.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-x))

# %%
print("Test Inputs:")
print(X_test)

print("Predicted Outputs:")
print(y_test_pred)

print("Actual Outputs (2x):")
print(2 * X_test)
# Out:
# Test Inputs:
# [[0.2]
#  [0.5]
#  [0.8]]
# Predicted Outputs:
# [[0.99984818]
#  [1.        ]
#  [1.        ]]
# Actual Outputs (2x):
# [[0.4]
#  [1. ]
#  [1.6]]
